# %% [markdown]
# <div style="text-align:center; border:2px solid black; font-size: 1.8em;">
# <h1>DS  : Programmation Objet</h1>
#     <br>
# </div>

# %% [markdown]
# <span style="color:red"><b><u>Ecrire votre prénom ici</u> :

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:DodgerBlue;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid DarkBlue;margin:0px 10px 10px 10px;padding:10px;">
#     Définir une classe <b>Poulailler</b>. <br><br>Cette classe possède trois attributs, <b>Nombre_de_poule</b>,   <b>Nombre_doeuf</b> et <b>Surface</b> ...
#     <ul><i>qui correspondent respectivement au nombre de poules, d'oeufs <u><b>initialement présent au lancement du poulailler, </b></u><br>
#         et à la surface du poulailler.
#         </ul>
#     <ul>
#             <li>Ecrire le constructeur de cette classe. Le constructeur doit lever une <b><span style="color:red">TypeError</span></b> si Nombre_de_poule ou si Nombre_doeuf fournis ne sont pas des entiers positifs ou nuls.</li>
#             <br>
#             <li>Ajouter une méthode spécifique qui renvoie une chaîne de caractère de la forme "Ce poulailler contient : 5 poules, et 0 oeufs.</li>
#             <br>
#         <li>Ajouter une méthode <b>surface_suffisante</b> qui renverra pour information, soit :<br><br>
#             <ul>
#                 <li>Ce poulailler a une surface suffisante pour son nombre de poules.</li>
#                 <ul>
#                     ou<br>
#                 </ul>
#                 <li>Ce poulailler n'a pas une surface suffisante pour son nombre de poules.</li>
#             </ul>
#         </li>
#         <br><ul><ul><b><span style="color:green">sachant que selon la norme européenne, une poule doit bénificier d'une surface de 1.5 m².</span></b>
#         </ul>
#         </ul>
#         <br><br>
#         <li>Ajouter une méthode <b>pondaison</b> qui prendra un argument : <b><i><span style="color:blue">ajout_jours_sans_visite</span></i></b> ;<br><br>
# <ul>
#     Sachant que :
#     <ul>
#         <li>1 poule pond 2 oeufs par jour.</li>
#         <ul><ul>... Donc, si l'argument ajout_jours_sans_visite = 3, et qu'initialement il y avait 0 oeufs, alors au bout des 3 jours, <u>on ramasse 6 oeufs... il en reste donc 0</u>.
#             </ul>
#         </ul><br>
#         Par ailleur : <br><br>
#         <li>Un renard passe 1 fois tous les 3 jours <b><u>de non-visite</u></b>.. et dévore 4 oeufs, et 1 poule !</li>
#         <br>
#         <ul><ul>
#             Donc, si vous avez attendu 7 jours avant de ramasser les oeufs... (ajout_jours_sans_visite = 7)<br>
#             <ul>alors <b>2 renards</b> on eu le temps de dévorer leurs 4 oeufs.. soit 8 oeufs au total, et 2 poules
#                 <ul>dans le même temps, les poules ont pondu leur 2 oeufs/jour.<br>
#                 </ul>
#             </ul>
#             </ul>
#         </ul>
#         <br>
#         Pour finir :
#         <br><br>
# <li>La méthode pondaison doit renvoyer exactement cette phrase :</li><br>
#             <ul><ul> Après 1 jours sans visite, on observe : 5 poules, et 10 oeufs dans le poulailler : je les ramasse.<br>
#                 <ul><ul><span style="color:blue">vos chiffres seront différents biensûr.</span>

# %% [markdown]
# <div style="border:2px solid DarkBlue;margin:0px 10px 10px 10px;padding:10px;">
# <u>Voici le genre de sortie que vous devez obtenir</u> :<br><br>
# Ce poulailler contient : 5 poules, et 0 oeufs.<br>
# Ce poulailler a une surface suffisante pour son nombre de poules.<br>
# Après 1 jours sans visite, on observe : 5 poules, et 10 oeufs dans le poulailler : je les ramasse.<br>
# Après 1 jours sans visite, on observe : 5 poules, et 10 oeufs dans le poulailler : je les ramasse.<br>
# Après 3 jours sans visite, on observe : 4 poules, et 26 oeufs dans le poulailler : je les ramasse.<br>
# Après 1 jours sans visite, on observe : 4 poules, et 8 oeufs dans le poulailler : je les ramasse.<br>
# Après 7 jours sans visite, on observe : 2 poules, et 48 oeufs dans le poulailler : je les ramasse.
